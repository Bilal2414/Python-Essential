# %% [markdown]
# Function is a block of code that do specific tasks

# %%
# Without using function
print("Welcome")
print("Welcome")
print("Welcome")
print("Welcome")
# Out:
# Welcome
# Welcome
# Welcome
# Welcome

# %%
# With using function
def welcome():
    print("Welcome")
welcome()   
welcome()   
welcome()
# Out:
# Welcome
# Welcome
# Welcome
